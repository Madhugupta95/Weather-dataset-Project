# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\madhu\Downloads\weather dataset.csv")

# %%
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %%
data.shape
# Out:
# (96453, 12)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)        int64
# Visibility (km)             float64
# Loud Cover                    int64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
data['Daily Summary'].unique()
# Out:
# array(['Partly cloudy throughout the day.',
#        'Mostly cloudy throughout the day.', 'Foggy in the evening.',
#        'Foggy overnight and breezy in the morning.',
#        'Overcast throughout the day.', 'Partly cloudy until night.',
#        'Mostly cloudy until night.',
#        'Foggy starting overnight continuing until morning.',
#        'Foggy in the morning.', 'Partly cloudy until evening.',
#        'Partly cloudy starting in the morning.',
#        'Mostly cloudy starting overnight continuing until night.',
#        'Mostly cloudy until evening.',
#        'Partly cloudy starting in the morning continuing until evening.',
#        'Partly cloudy starting in the afternoon.',
#        'Partly cloudy starting overnight.',
#        'Partly cloudy until morning.',
#        'Partly cloudy starting overnight continuing until night.',
#        'Partly cloudy starting in the afternoon continuing until night.',
#        'Mostly cloudy starting overnight.',
# ...

# %%
data.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
data.count()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %%
data['Daily Summary'].value_counts()
# Out:
# Mostly cloudy throughout the day.                                                                       20085
# Partly cloudy throughout the day.                                                                        9981
# Partly cloudy until night.                                                                               6169
# Partly cloudy starting in the morning.                                                                   5184
# Foggy in the morning.                                                                                    4201
#                                                                                                         ...
# Breezy starting overnight continuing until morning and foggy overnight.                                    24
# Mostly cloudy throughout the day and breezy starting overnight continuing until afternoon.                 24
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  int64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  int64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 8.8+ MB

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
data['Wind Speed (km/h)'].nunique()
# Out:
# 2484

# %%
data['Wind Speed (km/h)'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
# value_counts()
data['Daily Summary'].value_counts()
# Out:
# Mostly cloudy throughout the day.                                                                       20085
# Partly cloudy throughout the day.                                                                        9981
# Partly cloudy until night.                                                                               6169
# Partly cloudy starting in the morning.                                                                   5184
# Foggy in the morning.                                                                                    4201
#                                                                                                         ...
# Breezy starting overnight continuing until morning and foggy overnight.                                    24
# Mostly cloudy throughout the day and breezy starting overnight continuing until afternoon.                 24
# ...

# %%
# Filtering
data.head(2)
data[data.Summary == 'Clear']
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
# groupby()
data.head(2)
data.groupby('Summary').get_group('Clear')
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[data['Wind Speed (km/h)'] == 14.1197]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 618    2006-04-05 18:00:00.000 +0200       Overcast        rain
# 646    2006-04-06 22:00:00.000 +0200       Overcast        rain
# 1264   2006-08-03 16:00:00.000 +0200  Mostly Cloudy        rain
# 1885   2006-12-25 13:00:00.000 +0100  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 94761  2016-11-28 13:00:00.000 +0100  Mostly Cloudy        rain
# 94784  2016-11-29 12:00:00.000 +0100  Mostly Cloudy        rain
# 94785  2016-11-29 13:00:00.000 +0100  Mostly Cloudy        rain
# 94833  2016-11-30 13:00:00.000 +0100  Mostly Cloudy        rain
# 96371  2016-09-06 14:00:00.000 +0200  Mostly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.rename(columns = {'Daily Summary' : 'Weather Condition'}, inplace = True)

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                    Weather Condition
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.Humidity.mean()
# Out:
# 0.7348989663358906

# %%
data.Humidity.std()
# Out:
# 0.19547273906722662

# %%
data.Humidity.var()
# Out:
# 0.03820959171844407

# %%
# value_counts()
#data.head(2)
data['Weather Condition'].value_counts()
# Out:
# Mostly cloudy throughout the day.                                                                       20085
# Partly cloudy throughout the day.                                                                        9981
# Partly cloudy until night.                                                                               6169
# Partly cloudy starting in the morning.                                                                   5184
# Foggy in the morning.                                                                                    4201
#                                                                                                         ...
# Breezy starting overnight continuing until morning and foggy overnight.                                    24
# Mostly cloudy throughout the day and breezy starting overnight continuing until afternoon.                 24
# ...

# %%
# Filtering
data[data['Weather Condition'] == 'Foggy in the morning.']
# Out:
#                       Formatted Date        Summary Precip Type  \
# 312    2006-04-21 00:00:00.000 +0200  Mostly Cloudy        rain
# 313    2006-04-21 01:00:00.000 +0200          Foggy        rain
# 314    2006-04-21 02:00:00.000 +0200          Foggy        rain
# 315    2006-04-21 03:00:00.000 +0200       Overcast        rain
# 316    2006-04-21 04:00:00.000 +0200       Overcast        rain
# ...                              ...            ...         ...
# 95872  2016-09-14 19:00:00.000 +0200  Partly Cloudy        rain
# 95873  2016-09-14 20:00:00.000 +0200  Partly Cloudy        rain
# 95874  2016-09-14 21:00:00.000 +0200  Partly Cloudy        rain
# 95875  2016-09-14 22:00:00.000 +0200  Partly Cloudy        rain
# 95876  2016-09-14 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 312          11.527778                 11.527778      0.96             3.1556
# ...

# %%
# str.contains
data[data['Weather Condition'].str.contains('Foggy in the morning.')].tail(50)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 93594  2016-05-11 22:00:00.000 +0200  Mostly Cloudy        rain
# 93595  2016-05-11 23:00:00.000 +0200       Overcast        rain
# 95012  2016-10-10 00:00:00.000 +0200  Mostly Cloudy        rain
# 95013  2016-10-10 01:00:00.000 +0200  Mostly Cloudy        rain
# 95014  2016-10-10 02:00:00.000 +0200  Partly Cloudy        rain
# 95015  2016-10-10 03:00:00.000 +0200  Partly Cloudy        rain
# 95016  2016-10-10 04:00:00.000 +0200          Foggy        rain
# 95017  2016-10-10 05:00:00.000 +0200          Foggy        rain
# 95018  2016-10-10 06:00:00.000 +0200          Foggy        rain
# 95019  2016-10-10 07:00:00.000 +0200          Foggy        rain
# 95020  2016-10-10 08:00:00.000 +0200          Foggy        rain
# 95021  2016-10-10 09:00:00.000 +0200  Mostly Cloudy        rain
# 95022  2016-10-10 10:00:00.000 +0200  Mostly Cloudy        rain
# 95023  2016-10-10 11:00:00.000 +0200  Mostly Cloudy        rain
# ...

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                    Weather Condition
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[(data['Wind Speed (km/h)'] > 14.1197) & (data['Visibility (km)'] == 15.8263)]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 24     2006-04-10 00:00:00.000 +0200  Partly Cloudy        rain
# 25     2006-04-10 01:00:00.000 +0200  Partly Cloudy        rain
# 46     2006-04-10 22:00:00.000 +0200       Overcast        rain
# 48     2006-04-11 00:00:00.000 +0200       Overcast        rain
# ...                              ...            ...         ...
# 95289  2016-10-20 13:00:00.000 +0200  Partly Cloudy         NaN
# 95292  2016-10-20 16:00:00.000 +0200  Mostly Cloudy         NaN
# 95595  2016-10-04 06:00:00.000 +0200  Mostly Cloudy        rain
# 95637  2016-10-06 00:00:00.000 +0200  Mostly Cloudy        rain
# 95640  2016-10-06 03:00:00.000 +0200       Overcast        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 1             9.355556                  7.227778      0.86            14.2646
# ...

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                    Weather Condition
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.groupby('Weather Condition').mean()
# Out:
#                                                  Temperature (C)  \
# Weather Condition
# Breezy and foggy starting in the evening.               4.523843
# Breezy and foggy until morning.                        -4.869213
# Breezy and mostly cloudy overnight.                     3.755787
# Breezy and partly cloudy in the afternoon.             28.097917
# Breezy in the morning and foggy in the evening.         0.743750
# ...                                                          ...
# Partly cloudy until night.                             17.675495
# Rain throughout the day.                               10.128241
# Rain until afternoon.                                  11.701157
# Rain until morning.                                     9.304630
# Windy in the afternoon.                                 4.538889
#
#                                                  Apparent Temperature (C)  \
# Weather Condition
# ...

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                    Weather Condition
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[data['Weather Condition'] == 'Foggy in the morning.']
# Out:
#                       Formatted Date        Summary Precip Type  \
# 312    2006-04-21 00:00:00.000 +0200  Mostly Cloudy        rain
# 313    2006-04-21 01:00:00.000 +0200          Foggy        rain
# 314    2006-04-21 02:00:00.000 +0200          Foggy        rain
# 315    2006-04-21 03:00:00.000 +0200       Overcast        rain
# 316    2006-04-21 04:00:00.000 +0200       Overcast        rain
# ...                              ...            ...         ...
# 95872  2016-09-14 19:00:00.000 +0200  Partly Cloudy        rain
# 95873  2016-09-14 20:00:00.000 +0200  Partly Cloudy        rain
# 95874  2016-09-14 21:00:00.000 +0200  Partly Cloudy        rain
# 95875  2016-09-14 22:00:00.000 +0200  Partly Cloudy        rain
# 95876  2016-09-14 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 312          11.527778                 11.527778      0.96             3.1556
# ...

# %%
data[(data['Weather Condition'] == 'Foggy in the morning.') | (data['Humidity'] > 0.85)].head(25)
# Out:
#                    Formatted Date                   Summary Precip Type  \
# 0   2006-04-01 00:00:00.000 +0200             Partly Cloudy        rain
# 1   2006-04-01 01:00:00.000 +0200             Partly Cloudy        rain
# 2   2006-04-01 02:00:00.000 +0200             Mostly Cloudy        rain
# 6   2006-04-01 06:00:00.000 +0200             Partly Cloudy        rain
# 7   2006-04-01 07:00:00.000 +0200             Partly Cloudy        rain
# 50  2006-04-11 02:00:00.000 +0200                  Overcast        rain
# 52  2006-04-11 04:00:00.000 +0200                  Overcast        rain
# 53  2006-04-11 05:00:00.000 +0200                  Overcast        rain
# 54  2006-04-11 06:00:00.000 +0200             Mostly Cloudy        rain
# 55  2006-04-11 07:00:00.000 +0200             Mostly Cloudy        rain
# 65  2006-04-11 17:00:00.000 +0200                  Overcast        rain
# 66  2006-04-11 18:00:00.000 +0200                     Foggy        rain
# ...

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                    Weather Condition
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[(data['Weather Condition'] == 'Foggy in the morning.') & (data['Humidity'] > 0.89) | (data['Visibility (km)'] > 15.8263)]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96     2006-04-13 00:00:00.000 +0200  Mostly Cloudy        rain
# 97     2006-04-13 01:00:00.000 +0200       Overcast        rain
# 142    2006-04-14 22:00:00.000 +0200  Mostly Cloudy        rain
# 144    2006-04-15 00:00:00.000 +0200  Mostly Cloudy        rain
# 145    2006-04-15 01:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96445  2016-09-09 16:00:00.000 +0200  Partly Cloudy        rain
# 96447  2016-09-09 18:00:00.000 +0200  Partly Cloudy        rain
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96            7.316667                  6.211111      0.75             6.6654
# ...
